# %% [markdown]
# <a href="https://colab.research.google.com/github/jjgl0540-hub/GEOG5415/blob/main/01_data_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Leeds")
# Out:
# Hello Leeds
